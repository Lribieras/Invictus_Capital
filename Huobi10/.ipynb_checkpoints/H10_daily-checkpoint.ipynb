# %%
import numpy as np
import pandas as pd
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import axes
import pickle
from datetime import datetime
from scipy import log,exp,sqrt,stats
print('Packages')
# Out:
# Packages

# %%
# Importing pickle file
data = np.load('/Users/louisribieras/Desktop/IXPERIENCE/my_invictus/data/latest_coin_data.pkl')
# Drop Null Values
data = data.dropna()

print('Loading of Data')
print('shape of data: ', data.shape)
# Out:
# Loading of Data
# shape of data:  (133, 916)

# %%
print('Making Volumes dataframe: volumes')

# Initialize a close_price list
volumes_list = list()
# Making a list of all close_prices
for date in data.index:
    for column in data.columns:
        volumes_list.append(data[column][date]['volume'])

# Splitting list into 133 lists (one per coin)
volumes_list = [volumes_list[i:i+916] for i  in range(0, len(volumes_list), 916)]   

volumes = pd.DataFrame(data = volumes_list, index = data.index, columns = data.columns)
# Reordering column index
volumes = volumes[volumes.columns[::-1]]

# original date index
data_index = volumes.columns

# Index to Datetime index
volumes.columns = pd.to_datetime(volumes.columns)

# Deleting first day
# del volumes['2016-01-03 00:00:00']

print('Shape of Volumes df: ', volumes.shape)
volumes.head(3)
# Out:
# Making Volumes dataframe: volumes
# Shape of Volumes df:  (133, 916)
#                           2016-01-01  2016-01-02  2016-01-03  2016-01-04  \
# 1337coin                        24.0        12.0        11.0         3.0
# advanced-internet-blocks        80.0        60.0        75.0         4.0
# adzcoin                       1486.0      1269.0      1116.0      1134.0
#
#                           2016-01-05  2016-01-06  2016-01-07  2016-01-08  \
# 1337coin                        13.0         2.0        27.0        20.0
# advanced-internet-blocks        65.0        89.0        97.0       188.0
# adzcoin                       1151.0      1021.0      2124.0       842.0
#
#                           2016-01-09  2016-01-10     ...      2018-06-25  \
# 1337coin                        16.0       121.0     ...           219.0
# advanced-internet-blocks        91.0        34.0     ...             1.0
# adzcoin                        749.0       721.0     ...          1280.0
#
#                           2018-06-26  2018-06-27  2018-06-28  2018-06-29  \
# 1337coin                      2487.0      3683.0       764.0      4477.0
# advanced-internet-blocks        47.0         3.0         4.0        39.0
# adzcoin                       1804.0       312.0      1169.0      2599.0
#
#                           2018-06-30  2018-07-01  2018-07-02  2018-07-03  \
# 1337coin                       508.0       769.0     10084.0      1021.0
# advanced-internet-blocks         3.0         1.0        15.0        75.0
# adzcoin                       1172.0      2908.0      1480.0       925.0
#
#                           2018-07-04
# 1337coin                      2343.0
# advanced-internet-blocks        44.0
# adzcoin                        727.0
#
# [3 rows x 916 columns]

# %%
print('Close Price dataframe: close_df')
# Initialize a close_price list
close_list = list()
# Making a list of all close_prices
for date in data.index:
    for column in data.columns:
        close_list.append(data[column][date]['close_price'])

# Splitting list into 133 lists (one per coin)
close_list2 = [close_list[i:i+916] for i  in range(0, len(close_list), 916)]

# Making a Dataframe
close_df = pd.DataFrame(data = close_list2, index = data.index, columns = data.columns)

# Reordering columns
close_df = close_df[close_df.columns[::-1]]

# Index to Datetime index
close_df.columns = pd.to_datetime(close_df.columns)

# Deleting first day
# del close_df['2016-01-03 00:00:00']

close_df.head(3)
# Out:
# Close Price dataframe: close_df
#                           2016-01-01  2016-01-02  2016-01-03  2016-01-04  \
# 1337coin                    0.000013    0.000013    0.000013    0.000009
# advanced-internet-blocks    0.001429    0.000733    0.001475    0.003461
# adzcoin                     0.035203    0.033206    0.030144    0.024340
#
#                           2016-01-05  2016-01-06  2016-01-07  2016-01-08  \
# 1337coin                    0.000013    0.000010    0.000017    0.000019
# advanced-internet-blocks    0.003447    0.003425    0.003646    0.003581
# adzcoin                     0.032073    0.027896    0.017795    0.017245
#
#                           2016-01-09  2016-01-10     ...      2018-06-25  \
# 1337coin                    0.000022    0.000019     ...        0.000063
# advanced-internet-blocks    0.003536    0.008036     ...        0.005340
# adzcoin                     0.017908    0.017920     ...        0.021635
#
#                           2018-06-26  2018-06-27  2018-06-28  2018-06-29  \
# 1337coin                    0.000087    0.000111    0.000058    0.000062
# advanced-internet-blocks    0.002552    0.003626    0.003333    0.002476
# adzcoin                     0.019316    0.019415    0.019147    0.018698
#
#                           2018-06-30  2018-07-01  2018-07-02  2018-07-03  \
# 1337coin                    0.000061    0.000062    0.000066    0.000063
# advanced-internet-blocks    0.002682    0.002665    0.005060    0.005007
# adzcoin                     0.020574    0.016432    0.017592    0.018273
#
#                           2018-07-04
# 1337coin                    0.000065
# advanced-internet-blocks    0.005061
# adzcoin                     0.018122
#
# [3 rows x 916 columns]

# %%
print('Calculating pct_change in close prices per week: close_pct')
weekly_close_df2 = close_df.copy().T
close_pct = weekly_close_df2.pct_change(1).T
close_pct.head(5)
# Out:
# Calculating pct_change in close prices per week: close_pct
#                           2016-01-01  2016-01-02  2016-01-03  2016-01-04  \
# 1337coin                         NaN    0.000000    0.000000   -0.307692
# advanced-internet-blocks         NaN   -0.487054    1.012278    1.346441
# adzcoin                          NaN   -0.056728   -0.092212   -0.192542
# aeon                             NaN   -0.075457   -0.005119   -0.090151
# anarchistsprime                  NaN    0.037129   -0.031026   -0.007389
#
#                           2016-01-05  2016-01-06  2016-01-07  2016-01-08  \
# 1337coin                    0.444444   -0.230769    0.700000    0.117647
# advanced-internet-blocks   -0.004045   -0.006382    0.064526   -0.017828
# adzcoin                     0.317707   -0.130234   -0.362095   -0.030908
# aeon                        0.066587   -0.038981    0.035434   -0.081651
# anarchistsprime            -0.057072   -0.050000    0.058172    0.020942
#
#                           2016-01-09  2016-01-10     ...      2018-06-25  \
# 1337coin                    0.157895   -0.136364     ...       -0.015625
# advanced-internet-blocks   -0.012566    1.272624     ...        0.155344
# adzcoin                     0.038446    0.000670     ...        0.001806
# aeon                       -0.085560   -0.347006     ...        0.017094
# anarchistsprime            -0.046154   -0.032258     ...       -0.007099
#
#                           2018-06-26  2018-06-27  2018-06-28  2018-06-29  \
# 1337coin                    0.380952    0.275862   -0.477477    0.068966
# advanced-internet-blocks   -0.522097    0.420846   -0.080805   -0.257126
# adzcoin                    -0.107187    0.005125   -0.013804   -0.023450
# aeon                       -0.016807    0.017094   -0.050420    0.026549
# anarchistsprime            -0.275111    0.007985   -0.043336   -0.034096
#
#                           2018-06-30  2018-07-01  2018-07-02  2018-07-03  \
# 1337coin                   -0.016129    0.016393    0.064516   -0.045455
# advanced-internet-blocks    0.083199   -0.006339    0.898687   -0.010474
# adzcoin                     0.100332   -0.201322    0.070594    0.038711
# aeon                        0.060345    0.016260    0.064000   -0.037594
# anarchistsprime             0.030257    0.366618    0.041189   -0.015824
#
#                           2018-07-04
# 1337coin                    0.031746
# advanced-internet-blocks    0.010785
# adzcoin                    -0.008264
# aeon                        0.023438
# anarchistsprime             0.010835
#
# [5 rows x 916 columns]

# %%
# Reverting Index
close_df.columns = data_index
volumes.columns = data_index
print('Reverting Index')
# Out:
# Reverting Index

# %%
print('Making weekly DataFrames: dv["date"]')
# Making weekly DataFrames
dv = {}
for day in volumes:
    dv[day] = pd.DataFrame(volumes[day].sort_values(ascending=False).head(10))
    dv[day].columns = ['Volume']
# Out:
# Making weekly DataFrames: dv["date"]

# %%
print('Calculating Proportions')
print()
# Calculating Proportion of volume in total top 10
for day in volumes.columns:
    dv[day]['Proportion'] = (dv[day]['Volume'])/(dv[day]['Volume'].sum())
    
print(dv['Jan 01, 2016'])
print()
print('total:                  ', dv['Jan 01, 2016']['Proportion'].sum())
# Out:
# Calculating Proportions
#
#                Volume  Proportion
# bitcoin    36278900.0    0.899530
# litecoin    2791170.0    0.069207
# factom       502538.0    0.012460
# ripple       211767.0    0.005251
# ethereum     206062.0    0.005109
# dogecoin     105224.0    0.002609
# dash          98317.0    0.002438
# monero        88914.0    0.002205
# peercoin      29452.0    0.000730
# bitshares     18590.0    0.000461
#
# total:                   1.0

# %%
print('Corresponding Close Price & pct_change columns')
print('Creating simples and log lists')

coin_labels = list()
yesterday_list = close_df.columns[1::]
simple_list = list()
log_list = list()

for day in dv:
    coin_labels.append(dv[day].index)      

# Adding close_price columns for top 10 coins
for (day, coin, prior) in zip(close_df.columns, coin_labels, yesterday_list):
    dv[day]['close_price'] = close_df[day][coin]
    dv[day]['prior_close'] = close_df[prior][coin]
    dv[day]['pct_change_close'] = close_pct[day][coin]
    dv[day]['simple_returns'] = dv[day]['Proportion']*dv[day]['pct_change_close']
    dv[day]['logs'] = np.log((dv[day]['close_price'])/(dv[day]['prior_close']))
    dv[day]['prop_logs'] = dv[day]['Proportion']*dv[day]['logs']
    simple_list.append(sum(dv[day]['simple_returns']))
    log_list.append(sum(dv[day]['prop_logs']))
    
    
print('Weekly DataFrames with: Volume, Proportion, Close_Price, Pct_Change')
print()
print('Jan 08, 2016')
# Setting NaN values of jan 1, 2016 to 0
# dv['Jan 01, 2016']['pct_change_close'] = 0
dv['Jan 08, 2016']
# Out:
# Corresponding Close Price & pct_change columns
# Creating simples and log lists
# Weekly DataFrames with: Volume, Proportion, Close_Price, Pct_Change
#
# Jan 08, 2016
#                Volume  Proportion  close_price  prior_close  pct_change_close  \
# bitcoin    56993000.0    0.906523   453.230000   447.610000         -0.010523
# litecoin    3277990.0    0.052139     3.570000     3.560000         -0.008333
# factom      1159720.0    0.018446     0.733420     0.767838          0.258181
# ethereum     545600.0    0.008678     0.986789     0.986833          0.047541
# dogecoin     306716.0    0.004879     0.000158     0.000180          0.136691
# ripple       288641.0    0.004591     0.005933     0.005982         -0.017553
# bitshares    146358.0    0.002328     0.002921     0.003140         -0.019470
# dash          76706.0    0.001220     3.310000     3.180000         -0.020710
# nubits        37919.0    0.000603     0.995312     0.990908         -0.001658
# blackcoin     37258.0    0.000593     0.024708     0.025557         -0.026631
#
#            simple_returns      logs     prop_logs
# bitcoin         -0.009539  0.012477  1.131105e-02
# litecoin        -0.000434  0.002805  1.462533e-04
# factom           0.004762 -0.045860 -8.459539e-04
# ethereum         0.000413 -0.000045 -3.869459e-07
# dogecoin         0.000667 -0.130362 -6.359808e-04
# ripple          -0.000081 -0.008225 -3.776154e-05
# bitshares       -0.000045 -0.072297 -1.683033e-04
# dash            -0.000025  0.040067  4.888473e-05
# nubits          -0.000001  0.004435  2.674636e-06
# blackcoin       -0.000016 -0.033784 -2.002120e-05

# %%
print('Daily Returns Dataframe')
Returns_D = pd.DataFrame(data = simple_list, index = volumes.columns[1:], 
                       columns = ['Simple_Returns'])
Returns_D['Log_Returns'] = log_list
Returns_D['Cum_Simple_Returns'] = (1 + Returns_D['Simple_Returns']).cumprod()
Returns_D['Cum_Log_Returns'] = Returns_D['Log_Returns'].cumsum()

Returns_D.head(5)
# Out:
# Daily Returns Dataframe
#               Simple_Returns  Log_Returns  Cum_Simple_Returns  Cum_Log_Returns
# Jan 02, 2016             NaN     0.000702                 NaN         0.000702
# Jan 03, 2016        0.000203     0.007492            1.000203         0.008194
# Jan 04, 2016       -0.007438    -0.006239            0.992764         0.001954
# Jan 05, 2016        0.006084     0.002714            0.998804         0.004669
# Jan 06, 2016       -0.001683     0.006484            0.997123         0.011153

# %%
volatility = np.std(Returns_D['Log_Returns'], axis = 0)*100
print('Volatility: ', volatility, '%')
# Out:
# Volatility:  3.9223473620117972 %

# %%
Returns_D

# %%
Returns_D.iloc[250:300]
# Out:
#               Simple_Returns  Log_Returns  Cum_Simple_Returns  Cum_Log_Returns
# Sep 08, 2016       -0.006534    -0.021203            8.264832        -0.538360
# Sep 09, 2016        0.180119     0.014525            9.753482        -0.523835
# Sep 10, 2016       -0.005823     0.003944            9.696689        -0.519891
# Sep 11, 2016        0.004151     0.043123            9.736940        -0.476768
# Sep 12, 2016       -0.040358     0.003545            9.343974        -0.473223
# Sep 13, 2016        0.003423    -0.009411            9.375956        -0.482634
# Sep 14, 2016        0.043782     0.004045            9.786452        -0.478589
# Sep 15, 2016       -0.000745     0.014045            9.779160        -0.464544
# Sep 16, 2016        0.053266     0.020836           10.300061        -0.443708
# Sep 17, 2016       -0.007348     0.000558           10.224381        -0.443150
# Sep 18, 2016        0.008500     0.000295           10.311288        -0.442855
# Sep 19, 2016       -0.002731    -0.017968           10.283130        -0.460823
# Sep 20, 2016        0.019080    -0.017885           10.479328        -0.478708
# Sep 21, 2016        0.027255     0.033179           10.764940        -0.445529
# Sep 22, 2016       -0.027271     0.009471           10.471364        -0.436057
# Sep 23, 2016       -0.010597    -0.011753           10.360395        -0.447810
# Sep 24, 2016        0.013628     0.002728           10.501583        -0.445082
# Sep 25, 2016       -0.001878    -0.000285           10.481863        -0.445366
# Sep 26, 2016        0.004702    -0.003197           10.531151        -0.448563
# Sep 27, 2016        0.000270    -0.003054           10.533998        -0.451617
# Sep 28, 2016        0.002625    -0.008203           10.561653        -0.459820
# Sep 29, 2016        0.014314     0.004890           10.712834        -0.454930
# Sep 30, 2016       -0.006667    -0.002337           10.641416        -0.457267
# Oct 01, 2016        0.003210     0.012922           10.675572        -0.444346
# Oct 02, 2016       -0.020756    -0.007365           10.453989        -0.451710
# Oct 03, 2016        0.008723     0.002425           10.545183        -0.449285
# Oct 04, 2016        0.000966     0.006150           10.555374        -0.443136
# Oct 05, 2016        0.001525     0.007096           10.571469        -0.436039
# Oct 06, 2016       -0.012698    -0.004737           10.437237        -0.440776
# Oct 07, 2016        0.002193     0.000607           10.460125        -0.440169
# Oct 08, 2016        0.000503     0.001861           10.465390        -0.438308
# Oct 09, 2016        0.001490    -0.001679           10.480981        -0.439988
# Oct 10, 2016        0.012031    -0.013545           10.607074        -0.453532
# Oct 11, 2016        0.062185     0.026069           11.266677        -0.427464
# Oct 12, 2016        0.009438     0.003127           11.373014        -0.424337
# Oct 13, 2016       -0.004787    -0.005559           11.318576        -0.429896
# Oct 14, 2016        0.012080     0.005377           11.455300        -0.424519
# Oct 15, 2016        0.003815     0.006374           11.499007        -0.418145
# Oct 16, 2016       -0.004476    -0.002839           11.447532        -0.420984
# Oct 17, 2016        0.005286    -0.000214           11.508047        -0.421199
# Oct 18, 2016        0.005228    -0.003290           11.568211        -0.424488
# Oct 19, 2016        0.008816     0.022909           11.670193        -0.401579
# Oct 20, 2016       -0.012920    -0.002925           11.519415        -0.404505
# Oct 21, 2016        0.006019    -0.006272           11.588751        -0.410777
# Oct 22, 2016        0.005935    -0.026676           11.657530        -0.437453
# Oct 23, 2016        0.029488    -0.000282           12.001292        -0.437736
# Oct 24, 2016        0.000423     0.005819           12.006363        -0.431916
# Oct 25, 2016       -0.005872     0.000958           11.935858        -0.430959
# Oct 26, 2016       -0.005563    -0.025366           11.869463        -0.456325
# Oct 27, 2016        0.026230    -0.011252           12.180800        -0.467577

# %%
plt.plot(Returns_D['Cum_Simple_Returns'], linewidth = 1)
plt.plot()
plt.axhline(0, color='red', linewidth = 0.5)
plt.title('Huobi10 Index: Cumulative Simple Returns', fontsize = 18)
plt.rcParams['figure.figsize'] = (10,10)
plt.grid(color='black', linestyle='-', linewidth=0.05)
plt.xticks(np.arange(0,916,step=30), rotation=90, fontsize = 10)
plt.yticks(fontsize = 14)
plt.show()

# %%
plt.plot(Returns_D['Simple_Returns'], linewidth = 1)
plt.plot()
plt.axhline(0, color='red', linewidth = 0.5)
plt.title('Huobi10 Index: Simple Weekly Returns', fontsize = 18)
plt.rcParams['figure.figsize'] = (10,10)
plt.grid(color='black', linestyle='-', linewidth=0.05)
plt.xticks(np.arange(0,916,step=30), rotation=90, fontsize = 10)
plt.yticks(fontsize = 14)
plt.show()
