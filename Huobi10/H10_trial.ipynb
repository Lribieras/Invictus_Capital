# %%
import numpy as np
import pandas as pd
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import pickle
from datetime import datetime
from scipy import log,exp,sqrt,stats
print('Packages')
# Out:
# Packages

# %%
# Importing pickle file
data = np.load('/Users/louisribieras/Desktop/IXPERIENCE/my_invictus/data/latest_coin_data.pkl')
# Drop Null Values
data = data.dropna()

print('Loading of Data')
print('shape of data: ', data.shape)
# Out:
# Loading of Data
# shape of data:  (133, 916)

# %%
print('Making Volumes dataframe: volumes')

# Initialize a close_price list
volumes_list = list()
# Making a list of all close_prices
for date in data.index:
    for column in data.columns:
        volumes_list.append(data[column][date]['volume'])

# Splitting list into 133 lists (one per coin)
volumes_list = [volumes_list[i:i+916] for i  in range(0, len(volumes_list), 916)]
# Out:
# Making Volumes dataframe: volumes

# %%
volumes = pd.DataFrame(data = volumes_list, index = data.index, columns = data.columns)
# Reordering column index
volumes = volumes[volumes.columns[::-1]]

# original date index
data_index = volumes.columns[::7]

# Index to Datetime index
volumes.columns = pd.to_datetime(volumes.columns)

# Weekly Median close_df
volumes = volumes.resample('W', axis = 1).median()

# Deleting first day
del volumes['2016-01-03 00:00:00']

print('Shape of Volumes df: ', volumes.shape)
volumes.head(3)
# Out:
# Shape of Volumes df:  (133, 131)
#                           2016-01-10  2016-01-17  2016-01-24  2016-01-31  \
# 1337coin                        16.0        14.0        36.0        80.0
# advanced-internet-blocks        89.0        88.0        84.0         9.0
# adzcoin                       1021.0       917.0       319.0       843.0
#
#                           2016-02-07  2016-02-14  2016-02-21  2016-02-28  \
# 1337coin                        42.0        57.0       149.0       136.0
# advanced-internet-blocks         4.0         1.0         2.0         2.0
# adzcoin                        325.0       268.0       418.0       209.0
#
#                           2016-03-06  2016-03-13     ...      2018-05-06  \
# 1337coin                       242.0       241.0     ...          3693.0
# advanced-internet-blocks         1.0       757.0     ...            34.0
# adzcoin                        267.0      1254.0     ...          4292.0
#
#                           2018-05-13  2018-05-20  2018-05-27  2018-06-03  \
# 1337coin                      1920.0      6996.0      2476.0      1274.0
# advanced-internet-blocks       364.0         9.0         4.0         4.0
# adzcoin                       2605.0      1886.0      5867.0      5149.0
#
#                           2018-06-10  2018-06-17  2018-06-24  2018-07-01  \
# 1337coin                      1941.0      1257.0      1778.0       769.0
# advanced-internet-blocks        10.0        16.0         9.0         3.0
# adzcoin                       7427.0      1724.0      2537.0      1280.0
#
#                           2018-07-08
# 1337coin                      2343.0
# advanced-internet-blocks        44.0
# adzcoin                        925.0
#
# [3 rows x 131 columns]

# %%
print('Close Price dataframe: close_df')
# Initialize a close_price list
close_list = list()
# Making a list of all close_prices
for date in data.index:
    for column in data.columns:
        close_list.append(data[column][date]['close_price'])

# Splitting list into 133 lists (one per coin)
close_list2 = [close_list[i:i+916] for i  in range(0, len(close_list), 916)]

# Making a Dataframe
close_df = pd.DataFrame(data = close_list2, index = data.index, columns = data.columns)

# Reordering columns
close_df = close_df[close_df.columns[::-1]]

# Index to Datetime index
close_df.columns = pd.to_datetime(close_df.columns)

# Weekly Median close_df
close_df = close_df.resample('W', axis = 1).median()

# Deleting first day
del close_df['2016-01-03 00:00:00']

close_df.head(3)
# Out:
# Close Price dataframe: close_df
#                           2016-01-10  2016-01-17  2016-01-24  2016-01-31  \
# 1337coin                    0.000017    0.000018    0.000027    0.000034
# advanced-internet-blocks    0.003536    0.006535    0.006204    0.004655
# adzcoin                     0.017920    0.021857    0.021348    0.019708
#
#                           2016-02-07  2016-02-14  2016-02-21  2016-02-28  \
# 1337coin                    0.000027    0.000027    0.000037    0.000037
# advanced-internet-blocks    0.004728    0.004559    0.005491    0.005611
# adzcoin                     0.012962    0.013454    0.011872    0.007935
#
#                           2016-03-06  2016-03-13     ...      2018-05-06  \
# 1337coin                    0.000033    0.000030     ...        0.000162
# advanced-internet-blocks    0.007243    0.006986     ...        0.004195
# adzcoin                     0.013150    0.025035     ...        0.023653
#
#                           2018-05-13  2018-05-20  2018-05-27  2018-06-03  \
# 1337coin                    0.000141    0.000115    0.000092    0.000086
# advanced-internet-blocks    0.005302    0.004171    0.003280    0.002620
# adzcoin                     0.020782    0.018950    0.017137    0.017344
#
#                           2018-06-10  2018-06-17  2018-06-24  2018-07-01  \
# 1337coin                    0.000086    0.000075    0.000075    0.000062
# advanced-internet-blocks    0.002574    0.002149    0.004627    0.002682
# adzcoin                     0.017028    0.018151    0.023448    0.019316
#
#                           2018-07-08
# 1337coin                    0.000065
# advanced-internet-blocks    0.005060
# adzcoin                     0.018122
#
# [3 rows x 131 columns]

# %%
# Reverting Index
close_df.columns = data_index
volumes.columns = data_index
print('Reverting Index')
# Out:
# Reverting Index

# %%
print('Calculating pct_change in close prices per week: close_pct')
weekly_close_df2 = close_df.copy().T
close_pct = weekly_close_df2.pct_change(1).T
close_pct.head(5)
# Out:
# Calculating pct_change in close prices per week: close_pct
#                           Jan 01, 2016  Jan 08, 2016  Jan 15, 2016  \
# 1337coin                           NaN      0.058824      0.500000
# advanced-internet-blocks           NaN      0.848133     -0.050650
# adzcoin                            NaN      0.219699     -0.023288
# aeon                               NaN     -0.228037     -0.013310
# anarchistsprime                    NaN     -0.128947     -0.444109
#
#                           Jan 22, 2016  Jan 29, 2016  Feb 05, 2016  \
# 1337coin                      0.259259     -0.205882      0.000000
# advanced-internet-blocks     -0.249678      0.015682     -0.035745
# adzcoin                      -0.076822     -0.342298      0.037957
# aeon                         -0.123079      0.334605      0.030021
# anarchistsprime              -0.059783      1.375723     -0.104623
#
#                           Feb 12, 2016  Feb 19, 2016  Feb 26, 2016  \
# 1337coin                      0.370370      0.000000     -0.108108
# advanced-internet-blocks      0.204431      0.021854      0.290857
# adzcoin                      -0.117586     -0.331621      0.657215
# aeon                          0.151631      0.045797      0.184385
# anarchistsprime              -0.111413      1.437309      0.094103
#
#                           Mar 04, 2016      ...       Apr 27, 2018  \
# 1337coin                     -0.090909      ...          -0.084746
# advanced-internet-blocks     -0.035483      ...          -0.092973
# adzcoin                       0.903802      ...          -0.232145
# aeon                         -0.013257      ...          -0.059113
# anarchistsprime               0.548165      ...          -0.023238
#
#                           May 04, 2018  May 11, 2018  May 18, 2018  \
# 1337coin                     -0.129630     -0.184397     -0.200000
# advanced-internet-blocks      0.263886     -0.213316     -0.213618
# adzcoin                      -0.121380     -0.088153     -0.095673
# aeon                         -0.005236     -0.005263     -0.158730
# anarchistsprime              -0.356286     -0.009615      0.290049
#
#                           May 25, 2018  Jun 01, 2018  Jun 08, 2018  \
# 1337coin                     -0.065217      0.000000     -0.127907
# advanced-internet-blocks     -0.201220     -0.017557     -0.165113
# adzcoin                       0.012079     -0.018220      0.065950
# aeon                          0.050314     -0.023952     -0.110429
# anarchistsprime              -0.044920      0.070426     -0.158040
#
#                           Jun 15, 2018  Jun 22, 2018  Jun 29, 2018
# 1337coin                      0.000000     -0.173333      0.048387
# advanced-internet-blocks      1.153094     -0.420359      0.886652
# adzcoin                       0.291830     -0.176220     -0.061814
# aeon                         -0.075862     -0.111940      0.100840
# anarchistsprime              -0.045082     -0.390844      0.358384
#
# [5 rows x 131 columns]

# %%
print('Making weekly DataFrames: wv["date"]')
# Making weekly DataFrames
wv = {}
for week in volumes:
    wv[week] = pd.DataFrame(volumes[week].sort_values(ascending=False).head(10))
    wv[week].columns = ['Volume']
# Out:
# Making weekly DataFrames: wv["date"]

# %%
print('Calculating Proportions')
print()
# Calculating Proportion of volume in total top 10
for week in volumes.columns:
    wv[week]['Proportion'] = (wv[week]['Volume'])/(wv[week]['Volume'].sum())
    
print(wv['Jan 08, 2016'])
print()
print('total:                  ', wv['Jan 01, 2016']['Proportion'].sum())
# Out:
# Calculating Proportions
#
#                 Volume  Proportion
# bitcoin    115607000.0    0.942270
# litecoin     4170270.0    0.033990
# ethereum     1171150.0    0.009546
# factom        484656.0    0.003950
# ripple        441054.0    0.003595
# dogecoin      240252.0    0.001958
# dash          176887.0    0.001442
# bitshares     166116.0    0.001354
# peercoin      165177.0    0.001346
# nxt            67390.0    0.000549
#
# total:                   1.0000000000000002

# %%
print('Corresponding Close Price & pct_change columns')

coin_labels = list()
last_week_list = close_df.columns[1::]

for week in wv:
    coin_labels.append(wv[week].index)      

# Adding close_price columns for top 10 coins
for (week, coin, last_week) in zip(close_df.columns, coin_labels, last_week_list):
    wv[week]['close_price'] = close_df[week][coin]
    wv[week]['prior_close'] = close_df[last_week][coin]
    wv[week]['pct_change_close'] = close_pct[week][coin]
    wv[week]['simple_returns'] = wv[week]['Proportion']*wv[week]['pct_change_close']
    
print('Weekly DataFrames with: Volume, Proportion, Close_Price, Pct_Change')
print()
print('Jan 08, 2016')
# Setting NaN values of jan 1, 2016 to 0
wv['Jan 01, 2016']['pct_change_close'] = 0
wv['Jan 08, 2016']
# Out:
# Corresponding Close Price & pct_change columns
# Weekly DataFrames with: Volume, Proportion, Close_Price, Pct_Change
#
# Jan 08, 2016
#                 Volume  Proportion  close_price  prior_close  \
# bitcoin    115607000.0    0.942270   430.310000   387.490000
# litecoin     4170270.0    0.033990     3.470000     3.100000
# ethereum     1171150.0    0.009546     1.190000     1.530000
# factom        484656.0    0.003950     0.967830     0.991766
# ripple        441054.0    0.003595     0.005529     0.005271
# dogecoin      240252.0    0.001958     0.000171     0.000168
# dash          176887.0    0.001442     3.360000     4.490000
# bitshares     166116.0    0.001354     0.003078     0.003043
# peercoin      165177.0    0.001346     0.424689     0.399574
# nxt            67390.0    0.000549     0.007073     0.007118
#
#            pct_change_close  simple_returns
# bitcoin           -0.038650       -0.036418
# litecoin          -0.019774       -0.000672
# ethereum           0.246752        0.002355
# factom             0.552042        0.002181
# ripple            -0.075727       -0.000272
# dogecoin           0.187500        0.000367
# dash               0.012048        0.000017
# bitshares         -0.019745       -0.000027
# peercoin           0.020345        0.000027
# nxt                0.094214        0.000052

# %%
print("DataFrame with Weekly Returns: Weekly_Returns")

simple_returns_list = list()

for week in volumes.columns:
    simple_returns_list.append(sum(wv[week]['simple_returns']))
# Out:
# DataFrame with Weekly Returns: Weekly_Returns
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'simple_returns'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-47ea31291f98> in <module>()
#       4
#       5 for week in volumes.columns:
# ----> 6     simple_returns_list.append(sum(wv[week]['simple_returns']))
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'simple_returns'

# %%
Simple_Returns = pd.DataFrame(data = simple_returns_list)
Simple_Returns.columns = ['Simple_Returns']
Simple_Returns.index = volumes.columns[1:]
Simple_Returns.head(5)
# Out:
#               Simple_Returns
# Jan 08, 2016             NaN
# Jan 15, 2016       -0.032390
# Jan 22, 2016       -0.077951
# Jan 29, 2016        0.073497
# Feb 05, 2016       -0.006429

# %%
for week in wv:
    wv[week]['log_returns'] = np.log(wv[week].iloc[:,2])-np.log(wv[week].iloc[:,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-bb5072d3b902> in <module>()
#       1 for week in wv:
# ----> 2     wv[week]['log_returns'] = np.log(wv[week].iloc[:,2])-np.log(wv[week].iloc[:,3])
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     220                 raise IndexingError('Too many indexers')
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#     224                 raise ValueError("Location based indexing can only have "
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1955             return
#    1956         elif is_integer(key):
# -> 1957             self._validate_integer(key, axis)
#    1958         elif isinstance(key, tuple):
#    1959             # a tuple should already have been caught by this point
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
wv['Jan 08, 2016']
# Out:
#                 Volume  Proportion  close_price  prior_close  \
# bitcoin    115607000.0    0.942270   430.310000   387.490000
# litecoin     4170270.0    0.033990     3.470000     3.100000
# ethereum     1171150.0    0.009546     1.190000     1.530000
# factom        484656.0    0.003950     0.967830     0.991766
# ripple        441054.0    0.003595     0.005529     0.005271
# dogecoin      240252.0    0.001958     0.000171     0.000168
# dash          176887.0    0.001442     3.360000     4.490000
# bitshares     166116.0    0.001354     0.003078     0.003043
# peercoin      165177.0    0.001346     0.424689     0.399574
# nxt            67390.0    0.000549     0.007073     0.007118
#
#            pct_change_close  simple_returns  log_returns
# bitcoin           -0.038650       -0.036418     0.104816
# litecoin          -0.019774       -0.000672     0.112752
# ethereum           0.246752        0.002355    -0.251314
# factom             0.552042        0.002181    -0.024431
# ripple            -0.075727       -0.000272     0.047787
# dogecoin           0.187500        0.000367     0.017700
# dash               0.012048        0.000017    -0.289912
# bitshares         -0.019745       -0.000027     0.011436
# peercoin           0.020345        0.000027     0.060958
# nxt                0.094214        0.000052    -0.006342

# %%
print('log returns for each week (10coins)')
weekly_logs = list()

for week in wv:
    weekly_logs.append(wv[week]['Proportion'].dot(wv[week]['log_return'].T))
# Out:
# log returns for each week (10coins)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'log_return'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-f77bee578e09> in <module>()
#       3
#       4 for week in wv:
# ----> 5     weekly_logs.append(wv[week]['Proportion'].dot(wv[week]['log_return'].T))
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'log_return'

# %%
print('Simple and Log Returns')
Simple_Returns['log_returns'] = weekly_logs
Simple_Returns.head(5)
# Out:
# Simple and Log Returns
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a01f170e3dbd> in <module>()
#       1 print('Simple and Log Returns')
# ----> 2 Simple_Returns['log_returns'] = weekly_logs
#       3 Simple_Returns.head(5)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
print('Dropping First Week')
Simple_Returns = Simple_Returns.drop(Simple_Returns.index[0])
Simple_Returns.head(5)

# %%
Simple_Returns['Cum_simple_returns'] = Simple_Returns['Simple_Returns'].cumprod()
Simple_Returns.head(10)

# %%
plt.plot(Weekly_Returns['weekly_returns'], linewidth = 1)
plt.plot()
plt.axhline(0, color='red', linewidth = 0.5)
plt.title('Huobi10 Index: Weekly Returns', fontsize = 18)
plt.rcParams['figure.figsize'] = (10,5)
plt.grid(color='black', linestyle='-', linewidth=0.05)
plt.xticks(np.arange(0,131,step=4), rotation=90, fontsize = 10)
plt.yticks(fontsize = 14)
plt.show()

# %%
plt.plot(Weekly_Returns['log_returns'], linewidth = 1)
plt.plot()
plt.axhline(0, color='red', linewidth = 0.5)
plt.title('Huobi10 Index: Weekly Log Returns', fontsize = 18)
plt.rcParams['figure.figsize'] = (10,5)
plt.grid(color='black', linestyle='-', linewidth=0.05)
plt.xticks(np.arange(0,131,step=4), rotation=90, fontsize = 10)
plt.yticks(fontsize = 14)
plt.show()

# %%
plt.plot(Weekly_Returns['Cum_simple_returns'], linewidth = 1)
plt.plot()
plt.axhline(0, color='red', linewidth = 0.5)
plt.title('Huobi10 Index: CumSum Weekly Returns', fontsize = 18)
plt.rcParams['figure.figsize'] = (10,5)
plt.grid(color='black', linestyle='-', linewidth=0.05)
plt.xticks(np.arange(0,131,step=4), rotation=90, fontsize = 10)
plt.yticks(fontsize = 14)
plt.show()
